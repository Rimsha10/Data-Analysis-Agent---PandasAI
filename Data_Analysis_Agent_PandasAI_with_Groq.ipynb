# %% [markdown]
# # Imports necessary modules

# %%
# %pip install numpy==1.26.0
# %pip install pandas==1.5.3
# Out:
# Collecting numpy==1.26.0
#   Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.5/58.5 kB 3.8 MB/s eta 0:00:00
# Downloading numpy-1.26.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 47.8 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.0 which is incompatible.
# Successfully installed numpy-1.26.0
# Collecting pandas==1.5.3
#   Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3) (2025.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3) (1.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3) (1.17.0)
# Downloading pandas-1.5.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 102.1 MB/s eta 0:00:00
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 1.5.3 which is incompatible.
# cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# dask-cudf-cu12 25.6.0 requires pandas<2.2.4dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# mizani 0.13.5 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# plotnine 0.14.6 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# xarray 2025.3.1 requires pandas>=2.1, but you have pandas 1.5.3 which is incompatible.
# Successfully installed pandas-1.5.3

# %%
# %pip install langchain_groq
# Out:
# Collecting langchain_groq
#   Downloading langchain_groq-0.3.6-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.68 in /usr/local/lib/python3.11/dist-packages (from langchain_groq) (0.3.69)
# Collecting groq<1,>=0.29.0 (from langchain_groq)
#   Downloading groq-0.30.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /usr/local/lib/python3.11/dist-packages (from groq<1,>=0.29.0->langchain_groq) (4.14.1)
# Requirement already satisfied: langsmith>=0.3.45 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (0.4.6)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.68->langchain_groq) (25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->groq<1,>=0.29.0->langchain_groq) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain_groq) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain_groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain_groq) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.68->langchain_groq) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (3.11.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain_groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain_groq) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain_groq) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain_groq) (2.4.0)
# Downloading langchain_groq-0.3.6-py3-none-any.whl (16 kB)
# Downloading groq-0.30.0-py3-none-any.whl (131 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 9.0 MB/s eta 0:00:00
# Installing collected packages: groq, langchain_groq
# Successfully installed groq-0.30.0 langchain_groq-0.3.6

# %%
# %pip install pandasai
# Out:
# Collecting pandasai
#   Downloading pandasai-2.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting astor<0.9.0,>=0.8.1 (from pandasai)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: duckdb<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from pandasai) (1.2.2)
# Collecting faker<20.0.0,>=19.12.0 (from pandasai)
#   Downloading Faker-19.13.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from pandasai) (3.1.6)
# Requirement already satisfied: matplotlib<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from pandasai) (3.10.0)
# Requirement already satisfied: openai<2 in /usr/local/lib/python3.11/dist-packages (from pandasai) (1.96.1)
# Requirement already satisfied: pandas==1.5.3 in /usr/local/lib/python3.11/dist-packages (from pandasai) (1.5.3)
# Collecting pillow<11.0.0,>=10.1.0 (from pandasai)
#   Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.11/dist-packages (from pandasai) (2.11.7)
# Collecting python-dotenv<2.0.0,>=1.0.0 (from pandasai)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from pandasai) (2.32.3)
# Requirement already satisfied: scipy<2.0.0,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from pandasai) (1.15.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from pandasai) (2.0.41)
# Requirement already satisfied: sqlglot<26.0.0,>=25.0.3 in /usr/local/lib/python3.11/dist-packages (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai) (25.20.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3->pandasai) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3->pandasai) (2025.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from pandas==1.5.3->pandasai) (1.26.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.3->pandasai) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4.0.0,>=3.7.1->pandasai) (3.2.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai<2->pandasai) (4.14.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->pandasai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->pandasai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1->pandasai) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.31.0->pandasai) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4->pandasai) (3.2.3)
# Collecting sqlglotrs==0.2.12 (from sqlglot[rs]<26.0.0,>=25.0.3->pandasai)
#   Downloading sqlglotrs-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (546 bytes)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai<2->pandasai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2->pandasai) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->pandas==1.5.3->pandasai) (1.17.0)
# Downloading pandasai-2.3.0-py3-none-any.whl (185 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.0/186.0 kB 7.7 MB/s eta 0:00:00
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading Faker-19.13.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 37.9 MB/s eta 0:00:00
# Downloading pillow-10.4.0-cp311-cp311-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 43.2 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading sqlglotrs-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (334 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 334.4/334.4 kB 14.4 MB/s eta 0:00:00
# Installing collected packages: sqlglotrs, python-dotenv, pillow, astor, faker, pandasai
#   Attempting uninstall: pillow
#     Found existing installation: pillow 11.2.1
#     Uninstalling pillow-11.2.1:
#       Successfully uninstalled pillow-11.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# plotnine 0.14.6 requires pandas>=2.2.0, but you have pandas 1.5.3 which is incompatible.
# Successfully installed astor-0.8.1 faker-19.13.0 pandasai-2.3.0 pillow-10.4.0 python-dotenv-1.1.1 sqlglotrs-0.2.12

# %% [markdown]
# PandasAI🐼

# %%
# !pip show pandasai
# Out:
# Name: pandasai
# Version: 2.3.0
# Summary: Chat with your database (SQL, CSV, pandas, polars, mongodb, noSQL, etc). PandasAI makes data analysis conversational using LLMs (GPT 3.5 / 4, Anthropic, VertexAI) and RAG.
# Home-page:
# Author: Gabriele Venturi
# Author-email:
# License: MIT
# Location: /usr/local/lib/python3.11/dist-packages
# Requires: astor, duckdb, faker, jinja2, matplotlib, openai, pandas, pillow, pydantic, python-dotenv, requests, scipy, sqlalchemy, sqlglot
# Required-by:

# %% [markdown]
# # Import Data (csv)

# %% [markdown]
# The "Data Science Salaries" dataset provides valuable insights into the compensation trends and variations in the field of data science from 2020 to 2024

# %%
import pandas as pd
data = pd.read_csv("/content/ai_job_dataset.csv")
data.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             NaN
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# 4          Singapore           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
# 2     Kubernetes, Deep Learning, Java, Hadoop, NLP          Associate
# 3                        Scala, SQL, Linux, Python                PhD
# 4                     MLOps, Java, Tableau, Python             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive    18-Oct-24            07-Nov-24
# 1                 1       Media    20-Nov-24            11-Jan-25
# 2                 2   Education    18-Mar-25            07-Apr-25
# 3                 7  Consulting    23-Dec-24            24-Feb-25
# 4                 0       Media    15-Apr-25            23-Jun-25
#
#    benefits_score       company_name  job_description_length
# 0             5.9    Smart Analytics                  1076.0
# 1             5.2       TechCorp Inc                  1268.0
# 2             9.4    Autonomous Tech                  1974.0
# 3             8.6     Future Systems                  1345.0
# 4             6.6  Advanced Robotics                  1989.0

# %% [markdown]
# # LLM - using Groq API

# %%
import os
from langchain_groq.chat_models import ChatGroq
from google.colab import userdata

os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')
llm = ChatGroq(
    model_name="qwen/qwen3-32b",temperature=0)

# %%
field_descriptions = {
    'job_id': 'Unique identifier for each job posting',
    'job_title': 'Title or role being advertised',
    'salary_usd': 'Annual salary converted to USD for standardization',
    'salary_currency': 'Original currency in which the salary is offered',
    'experience_level': 'Experience level required (EN=Entry, MI=Mid, SE=Senior, EX=Executive)',
    'employment_type': 'Type of employment contract (FT=Full-time, PT=Part-time, CT=Contract, FL=Freelance)',
    'company_location': 'Country where the hiring company is based',
    'company_size': 'Size of the company (S=Small, M=Medium, L=Large)',
    'employee_residence': 'Country of residence of the employee or job seeker',
    'remote_ratio': 'Percentage of remote work allowed (0=Onsite, 50=Hybrid, 100=Remote)',
    'required_skills': 'List of key technical skills required (comma-separated)',
    'education_required': 'Minimum education level required for the job',
    'years_experience': 'Minimum years of experience required',
    'industry': 'Industry or sector to which the job belongs',
    'posting_date': 'Date when the job was posted (DD-MMM-YYYY)',
    'application_deadline': 'Last date to apply for the job (DD-MMM-YYYY)',
    'benefits_score': 'Score (0–10) reflecting the quality of job benefits',
    'company_name': 'Name of the company offering the job'
}

# %%
from pandasai.connectors import PandasConnector
data_df = PandasConnector({"original_df": data}, field_descriptions=field_descriptions)

# %% [markdown]
# # Custom Response

# %%
from pandasai.responses.response_parser import ResponseParser
from IPython.display import Image, display

class PandasDataFrame(ResponseParser):
    def __init__(self, context) -> None:
        super().__init__(context)
    def format_dataframe(self, result):
        return (result['value'])
    def format_plot(self, result):
        image_path = 'exports/charts/temp_chart.png'
        return display(Image(filename=image_path))
    def format_string(self, result):
        return result['value']

# %% [markdown]
# # Configurations
# * *llm*: LLM instance or name to use.
# * *save_logs*: Save LLM logs to pandasai.log (default: True).
# * *verbose*: Show logs in console (default: False).
# * *save_charts*: Save generated charts (default: False).
# * *save_charts_path*: Custom path to save charts (default: exports/charts/).
# * *open_charts*: Auto-open charts after generation (default: True).
# * *enable_cache*: Cache LLM responses to speed up (default: True).
# * *max_retries*: Retry count for error correction (default: 3).
# * *security*: Set to "none", "standard", or "advanced" for varying protection levels.

# %%
config={
        "llm": llm,
        "verbose": False,
        "use_error_correction_framework": True  ,
        "open_charts":False, "custom_whitelisted_dependencies": ['plotly'],"response_parser":PandasDataFrame

        }

# %% [markdown]
# # Preparing Agent

# %%
from pandasai import Agent
agent =  Agent(data_df,memory_size=5,
 description="You are a data analysis agent. Your main goal is to help non-technical users analyze data. ",
config=config)

# %% [markdown]
# # Talk with your Data

# %% [markdown]
# # *Data Cleaning*

# %%
agent.chat("How many rows are there?")
# Out:
# 15000

# %%
agent.chat("How many columns are there?")
# Out:
# 19

# %%
agent.chat("provide statistics about the data, in a table form")
# Out:
#                         count unique                          top   freq  \
# job_id                  15000  15000                      AI00001      1
# job_title               15000     20  Machine Learning Researcher    808
# salary_usd            15000.0    NaN                          NaN    NaN
# salary_currency         15000      3                          USD  11957
# experience_level        15000      4                           MI   3781
# employment_type         15000      4                           FT   3812
# company_location        15000     20                      Germany    814
# company_size            15000      3                            S   5007
# employee_residence      15000     20                       Sweden    790
# remote_ratio          15000.0    NaN                          NaN    NaN
# required_skills         15000  13663  Python, TensorFlow, PyTorch     17
# education_required      15000      4                     Bachelor   3789
# years_experience      15000.0    NaN                          NaN    NaN
# industry                15000     15                       Retail   1063
# posting_date            15000    486                    05-Jul-24     51
# application_deadline    15000    543                    05-Jan-25     47
# benefits_score        15000.0    NaN                          NaN    NaN
# company_name            15000     16                 TechCorp Inc    980
#
#                                mean           std      min       25%      50%  \
# job_id                          NaN           NaN      NaN       NaN      NaN
# job_title                       NaN           NaN      NaN       NaN      NaN
# salary_usd            115348.965133  60260.940438  32519.0  70179.75  99705.0
# salary_currency                 NaN           NaN      NaN       NaN      NaN
# experience_level                NaN           NaN      NaN       NaN      NaN
# employment_type                 NaN           NaN      NaN       NaN      NaN
# company_location                NaN           NaN      NaN       NaN      NaN
# company_size                    NaN           NaN      NaN       NaN      NaN
# employee_residence              NaN           NaN      NaN       NaN      NaN
# remote_ratio              49.483333     40.812712      0.0       0.0     50.0
# required_skills                 NaN           NaN      NaN       NaN      NaN
# education_required              NaN           NaN      NaN       NaN      NaN
# years_experience             6.2532      5.545768      0.0       2.0      5.0
# industry                        NaN           NaN      NaN       NaN      NaN
# posting_date                    NaN           NaN      NaN       NaN      NaN
# application_deadline            NaN           NaN      NaN       NaN      NaN
# benefits_score             7.504273       1.45087      5.0       6.2      7.5
# company_name                    NaN           NaN      NaN       NaN      NaN
#
#                            75%       max
# job_id                     NaN       NaN
# job_title                  NaN       NaN
# salary_usd            146408.5  399095.0
# salary_currency            NaN       NaN
# experience_level           NaN       NaN
# employment_type            NaN       NaN
# company_location           NaN       NaN
# company_size               NaN       NaN
# employee_residence         NaN       NaN
# remote_ratio             100.0     100.0
# required_skills            NaN       NaN
# education_required         NaN       NaN
# years_experience          10.0      19.0
# industry                   NaN       NaN
# posting_date               NaN       NaN
# application_deadline       NaN       NaN
# benefits_score             8.8      10.0
# company_name               NaN       NaN

# %%
agent.chat("provide statistics about the data for non numeric fields. in a table form")
# Out:
#                       Unique Count          Most Frequent Value  Frequency
# Column
# job_id                       15000                      AI00001          1
# job_title                       20  Machine Learning Researcher        808
# salary_currency                  3                          USD      11957
# experience_level                 4                           MI       3781
# employment_type                  4                           FT       3812
# company_location                20                      Germany        814
# company_size                     3                            S       5007
# employee_residence              20                       Sweden        790
# required_skills              13663  Python, TensorFlow, PyTorch         17
# education_required               4                     Bachelor       3789
# industry                        15                       Retail       1063
# posting_date                   486                    05-Jul-24         51
# application_deadline           543                    05-Jan-25         47
# company_name                    16                 TechCorp Inc        980

# %%
agent.chat("Show the missing values of data in tabular form")
# Out:
#                         Missing Count  Missing Percentage (%)
# job_description_length           1284                    8.56
# salary_currency                    15                    0.10

# %%
agent.chat("show the value of company location for which currency in null")
# Out:
#       company_location
# 4               France
# 113             France
# 209             France
# 255             France
# 9715            France
# 11604           France
# 11707           France
# 11817           France
# 11900           France
# 12519           France
# 13686           France
# 14532           France
# 14704           France
# 14803           France
# 14994           France

# %%
agent.chat("show the currency by company location")
# Out:
# salary_currency   EUR  GBP  USD  Unknown
# company_location
# Australia           0    0  732        0
# Austria             0    0  765        0
# Canada              0    0  769        0
# China               0    0  763        0
# Denmark             0    0  778        0
# Finland             0    0  733        0
# France            754    0    0       15
# Germany           814    0    0        0
# India               0    0  754        0
# Ireland             0    0  750        0
# Israel              0    0  751        0
# Japan               0    0  733        0
# Netherlands       731    0    0        0
# Norway              0    0  721        0
# Singapore           0    0  764        0
# South Korea         0    0  722        0
# Sweden              0    0  752        0
# Switzerland         0    0  746        0
# United Kingdom      0  729    0        0
# United States       0    0  724        0

# %%
agent.chat("impute the missing currency values by EUR, apply the changes to original data")
# Out:
# 'Missing currency values have been imputed with EUR.'

# %%
agent.chat("drop the job decription characters field from original data")
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio  \
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
#                                        required_skills education_required  \
# 0             Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1      Deep Learning, AWS, Mathematics, Python, Docker             Master
# 2         Kubernetes, Deep Learning, Java, Hadoop, NLP          Associate
# 3                            Scala, SQL, Linux, Python                PhD
# 4                         MLOps, Java, Tableau, Python             Master
# ...                                                ...                ...
# 14995                          Java, Kubernetes, Azure           Bachelor
# 14996          Mathematics, Docker, SQL, Deep Learning             Master
# 14997                                Scala, Spark, NLP          Associate
# 14998        Java, Computer Vision, Python, TensorFlow                PhD
# 14999    Scala, Azure, Deep Learning, GCP, Mathematics                PhD
#
#        years_experience       industry posting_date application_deadline  \
# 0                     9     Automotive    18-Oct-24            07-Nov-24
# 1                     1          Media    20-Nov-24            11-Jan-25
# 2                     2      Education    18-Mar-25            07-Apr-25
# 3                     7     Consulting    23-Dec-24            24-Feb-25
# 4                     0          Media    15-Apr-25            23-Jun-25
# ...                 ...            ...          ...                  ...
# 14995                 1         Energy    06-Feb-25            25-Mar-25
# 14996                 0     Government    16-Oct-24            30-Oct-24
# 14997                17  Manufacturing    19-Mar-24            02-May-24
# 14998                 1    Real Estate    22-Mar-24            23-Apr-24
# 14999                 2     Technology    18-Jul-24            10-Aug-24
#
#        benefits_score       company_name
# 0                 5.9    Smart Analytics
# 1                 5.2       TechCorp Inc
# 2                 9.4    Autonomous Tech
# 3                 8.6     Future Systems
# 4                 6.6  Advanced Robotics
# ...               ...                ...
# 14995             7.9  Advanced Robotics
# 14996             8.2    Smart Analytics
# 14997             7.4     AI Innovations
# 14998             5.6    Smart Analytics
# 14999             7.6     AI Innovations
#
# [15000 rows x 18 columns]

# %% [markdown]
# # Helper Functions

# %%
agent.last_code_executed

# %%
agent.rephrase_query()

# %%
agent.last_result
# Out:
# {'type': 'plot', 'value': '/content/exports/charts/temp_chart.png'}

# %%
agent.check_malicious_keywords_in_query("Tell me the comparison of highest salary offering companies for these 10 job titles. in a table")
# Out:
# False

# %%
agent.explain()
# Out:
# '<think>\nOkay, let\'s see. The user wants me to explain how I came up with the code in a way that\'s easy for non-technical people to understand. They don\'t want any technical details or mentions of the libraries used. So, I need to break it down into simple terms.\n\nFirst, the original code groups job data by education level and calculates the average salary for each. Then it creates a bar chart to visualize this. My explanation should focus on the process without mentioning pandas or matplotlib.\n\nI should start by explaining the goal: showing how education level affects average salary. Then, outline the steps taken. Maybe something like: "I looked at the data and grouped jobs by the education they require. For each group, I found the average salary. Then, I made a bar chart where each bar represents an education level and its corresponding average salary."\n\nI need to avoid terms like "groupby" or "bar plot." Instead, use everyday language. Also, mention that the chart is sorted from lowest to highest average salary. Make sure to explain why the chart is useful—so people can see the relationship between education and salary at a glance.\n\nCheck if there\'s anything else technical that needs simplifying. The user might not know what a dataframe is, so avoid that. Just focus on the logical steps and the purpose of each action. Keep it conversational and ensure each part is clear without jargon.\n</think>\n\nHere\'s a simple explanation of how I created the visualization:\n\n1. **Organized the data** - I grouped all the job listings by the education level they require (like high school, bachelor\'s, master\'s, etc.)\n\n2. **Calculated averages** - For each education group, I found the average salary to see what typical earnings look like at each level\n\n3. **Created a comparison chart** - I made a bar chart where:\n   - Each bar shows an education level\n   - The height of each bar shows the average salary for that level\n   - The bars are arranged from lowest to highest average salary\n\n4. **Formatted for clarity** - I made sure the chart is easy to read by:\n   - Using a clean color scheme\n   - Rotating the education labels so they\'re easy to read\n   - Adding clear labels for the salary numbers and education levels\n\nThe result is a visual comparison that shows how education requirements relate to average earnings across different job opportunities.'

# %%
agent.clear_memory
# Out:
# <bound method BaseAgent.clear_memory of <pandasai.agent.agent.Agent object at 0x7a12feaa9a50>>

# %% [markdown]
# # *Analyze Salary Insights*

# %% [markdown]
# 🔍 Objectives:
#
# * Identify Top paying job roles
# * See which are the best paying companies
# * Analyze salary by experience, Education and industry

# %%
agent.chat("Which job titles have the highest average salaries?")
# Out:
#                    Job Title  Average Salary (USD)
# 0              AI Specialist         120570.758242
# 1  Machine Learning Engineer         118827.919689
# 2                 Head of AI         118542.968627
# 3      AI Research Scientist         117897.925926
# 4               AI Architect         117436.513619
# 5          Robotics Engineer         116470.793149
# 6   Principal Data Scientist         116305.219346
# 7         Research Scientist         116066.502695
# 8              Data Engineer         115970.720961
# 9             Data Scientist         115819.008333

# %%
agent.chat("Provide the comparison of highest salary offering industries for these 10 job titles")

# %%
agent.chat("Tell me the comparison of highest salary offering companies for these 10 job titles. in a table")
# Out:
#                      job_title  salary_usd                company_name
# 0  Machine Learning Researcher      399095                TechCorp Inc
# 1                 AI Architect      398084              Future Systems
# 2        AI Research Scientist      394917  Machine Intelligence Group
# 3                AI Specialist      390292              DataVision Ltd
# 4               Data Scientist      388754           DeepTech Ventures
# 5           AI Product Manager      381575          Neural Networks Co
# 6         AI Software Engineer      379418       Algorithmic Solutions
# 7     Computer Vision Engineer      366957  Machine Intelligence Group
# 8     Principal Data Scientist      364635  Digital Transformation LLC
# 9  Autonomous Systems Engineer      364585          Cloud AI Solutions

# %%
agent.chat("Show the companies and countries which offer the highest salary for each job title")
# Out:
#                       job_title                company_name  salary_usd  \
# 0                  AI Architect              Future Systems      398084
# 1                 AI Consultant              AI Innovations      325757
# 2            AI Product Manager          Neural Networks Co      381575
# 3         AI Research Scientist  Machine Intelligence Group      394917
# 4          AI Software Engineer       Algorithmic Solutions      379418
# 5                 AI Specialist              DataVision Ltd      390292
# 6   Autonomous Systems Engineer          Cloud AI Solutions      364585
# 7      Computer Vision Engineer  Machine Intelligence Group      366957
# 8                  Data Analyst       Algorithmic Solutions      361541
# 9                 Data Engineer              Future Systems      359044
# 10               Data Scientist           DeepTech Ventures      388754
# 11       Deep Learning Engineer           DeepTech Ventures      362503
# 12                   Head of AI       Quantum Computing Inc      361718
# 13              ML Ops Engineer          Cloud AI Solutions      352006
# 14    Machine Learning Engineer  Digital Transformation LLC      344427
# 15  Machine Learning Researcher                TechCorp Inc      399095
# 16                 NLP Engineer  Machine Intelligence Group      357880
# 17     Principal Data Scientist  Digital Transformation LLC      364635
# 18           Research Scientist  Digital Transformation LLC      339526
# 19            Robotics Engineer           Advanced Robotics      346789
#
#    company_location
# 0       Switzerland
# 1           Denmark
# 2       Switzerland
# 3       Switzerland
# 4           Denmark
# 5       Switzerland
# 6           Denmark
# 7       Switzerland
# 8           Denmark
# 9       Switzerland
# 10      Switzerland
# 11           Norway
# 12          Denmark
# 13      Switzerland
# 14    United States
# 15      Switzerland
# 16      Switzerland
# 17      Switzerland
# 18           Norway
# 19           Norway

# %%
agent.chat("Show average salary grouped by experience level as a bar chart")

# %%
agent.chat("Plot the salary by company size for top 10 job titles")

# %%
agent.chat("Tell me the salary by education level in table")
# Out:
#   Education Level  Average Salary
# 0       Associate       114605.71
# 1        Bachelor       115861.63
# 2          Master       117171.82
# 3             PhD       113728.17

# %%
agent.chat("Visualize the result for me")

# %% [markdown]
# # *Find a job that meets these requirements*
# * Industry: Education
# * Job Title: Data Analyst, Data Engineer, Data Scientist
# * Remote: 100
# * Education: Bachelor
# * Experience: Entry level

# %%
agent.chat("Find the jobs for these requirements: Industry: Education, Job Title must be like Data Analyst, Data Engineer, Data Scientist, Remote: 100, Education: Bachelor, Experience: Entry level")
# Out:
#         job_id                 job_title  salary_usd salary_currency  \
# 1647   AI01648  Principal Data Scientist       65161             USD
# 2893   AI02894            Data Scientist      129525             USD
# 3487   AI03488              Data Analyst      131006             USD
# 9755   AI09756             Data Engineer       34984             USD
# 11965  AI11966              Data Analyst       54063             USD
#
#       experience_level employment_type company_location company_size  \
# 1647                EN              FT          Ireland            L
# 2893                EN              PT      Switzerland            L
# 3487                EN              FT      Switzerland            L
# 9755                EN              FL            India            S
# 11965               EN              FT            China            M
#
#       employee_residence  remote_ratio  \
# 1647             Ireland           100
# 2893             Finland           100
# 3487         Switzerland           100
# 9755              Sweden           100
# 11965            Ireland           100
#
#                                      required_skills education_required  \
# 1647                              Docker, NLP, Azure           Bachelor
# 2893                Java, PyTorch, Linux, TensorFlow           Bachelor
# 3487   Mathematics, Git, Java, Hadoop, Deep Learning           Bachelor
# 9755                        NLP, Hadoop, Spark, Java           Bachelor
# 11965                                Git, NLP, Linux           Bachelor
#
#        years_experience   industry posting_date application_deadline  \
# 1647                  1  Education    26-Jul-24            09-Aug-24
# 2893                  1  Education    30-Apr-25            13-Jun-25
# 3487                  1  Education    23-Jul-24            31-Aug-24
# 9755                  1  Education    17-Feb-25            29-Apr-25
# 11965                 1  Education    13-Dec-24            17-Feb-25
#
#        benefits_score           company_name standardized_job_title
# 1647              5.6           TechCorp Inc         Data Scientist
# 2893              7.0        Autonomous Tech         Data Scientist
# 3487              9.3  Algorithmic Solutions           Data Analyst
# 9755              7.7     Predictive Systems          Data Engineer
# 11965             7.4     Predictive Systems           Data Analyst

# %%
agent.chat("there is a change in requirement, the job can be less than 100 remote but then the location must be China and industry can be any.")
# Out:
#         job_id                 job_title  salary_usd salary_currency  \
# 16     AI00017  Principal Data Scientist       59823             USD
# 196    AI00197  Principal Data Scientist       49644             USD
# 209    AI00210              Data Analyst       48892             EUR
# 302    AI00303             Data Engineer       50471             USD
# 505    AI00506            Data Scientist       61289             EUR
# ...        ...                       ...         ...             ...
# 14450  AI14451             Data Engineer       55041             USD
# 14546  AI14547  Principal Data Scientist       51835             USD
# 14547  AI14548             Data Engineer       72358             USD
# 14574  AI14575              Data Analyst       94867             USD
# 14827  AI14828              Data Analyst       40297             USD
#
#       experience_level employment_type company_location company_size  \
# 16                  EN              FT            India            L
# 196                 EN              CT            China            L
# 209                 EN              CT           France            M
# 302                 EN              FT            China            S
# 505                 EN              FT          Germany            L
# ...                ...             ...              ...          ...
# 14450               EN              PT            India            L
# 14546               EN              PT            China            L
# 14547               EN              FL          Denmark            S
# 14574               EN              CT    United States            L
# 14827               EN              FT          Finland            S
#
#       employee_residence  remote_ratio  \
# 16                 India           100
# 196               Canada           100
# 209              Ireland           100
# 302                China           100
# 505              Germany           100
# ...                  ...           ...
# 14450            Denmark           100
# 14546              China            50
# 14547            Denmark           100
# 14574      United States           100
# 14827              Japan           100
#
#                                     required_skills education_required  \
# 16                              Tableau, NLP, Spark           Bachelor
# 196       Linux, PyTorch, TensorFlow, Azure, Python           Bachelor
# 209                              Linux, Python, NLP           Bachelor
# 302           Kubernetes, Scala, Data Visualization           Bachelor
# 505                              Python, PyTorch, R           Bachelor
# ...                                             ...                ...
# 14450                          Python, Scala, Spark           Bachelor
# 14546                      Java, PyTorch, R, Python           Bachelor
# 14547                          Kubernetes, AWS, SQL           Bachelor
# 14574                        Hadoop, Linux, PyTorch           Bachelor
# 14827  PyTorch, Git, Kubernetes, GCP, Deep Learning           Bachelor
#
#        years_experience            industry posting_date application_deadline  \
# 16                    1         Real Estate    06-Feb-25            26-Mar-25
# 196                   0             Finance    15-Feb-25            26-Mar-25
# 209                   0          Consulting    08-Oct-24            09-Dec-24
# 302                   1              Energy    19-Jan-25            26-Feb-25
# 505                   0             Finance    17-Oct-24            14-Nov-24
# ...                 ...                 ...          ...                  ...
# 14450                 1              Retail    26-Jun-24            30-Jul-24
# 14546                 0  Telecommunications    06-Nov-24            12-Jan-25
# 14547                 1          Consulting    22-Mar-24            16-Apr-24
# 14574                 1         Real Estate    01-Jul-24            27-Aug-24
# 14827                 1       Manufacturing    01-Apr-24            02-May-24
#
#        benefits_score                company_name standardized_job_title
# 16                5.8          Predictive Systems         Data Scientist
# 196               5.5              Future Systems         Data Scientist
# 209               6.6              DataVision Ltd           Data Analyst
# 302               9.1              DataVision Ltd          Data Engineer
# 505               5.7         Cognitive Computing         Data Scientist
# ...               ...                         ...                    ...
# 14450             8.5         Cognitive Computing          Data Engineer
# 14546             7.4  Machine Intelligence Group         Data Scientist
# 14547            10.0                TechCorp Inc          Data Engineer
# 14574             5.7              AI Innovations           Data Analyst
# 14827             9.3             Autonomous Tech           Data Analyst
#
# [73 rows x 19 columns]

# %%
agent.chat("What is the average salary for each of these job titles?")
# Out:
#         Job Title  Average Salary (USD)
# 0    Data Analyst             111321.18
# 1   Data Engineer             115970.72
# 2  Data Scientist             116064.45

# %%
agent.last_code_executed
# Out:
# "filtered_df = dfs[0][(dfs[0]['remote_ratio'] < 100) & (dfs[0]['company_location'] == 'China')]\naverage_salaries = filtered_df.groupby('job_title')['salary_usd'].mean().reset_index()\naverage_salaries.sort_values('salary_usd', ascending=False, inplace=True)\nplt.figure(figsize=(12, 8))\nplt.bar(average_salaries['job_title'], average_salaries['salary_usd'], color='skyblue')\nplt.xlabel('Job Title', fontsize=12)\nplt.ylabel('Average Salary (USD)', fontsize=12)\nplt.title('Average Salary by Job Title (China, Less than 100% Remote)', fontsize=14)\nplt.xticks(rotation=90, fontsize=10)\nplt.yticks(fontsize=10)\nplt.tight_layout()\nplt.savefig('/content/exports/charts/temp_chart.png')\nplt.close()\nresult = {'type': 'plot', 'value': '/content/exports/charts/temp_chart.png'}"

# %% [markdown]
# # *Analyze Application Duration*

# %%
agent.chat("Tell me the average application duration for job postings by job title and sort the results.")

# %%
agent.chat("Show the average application duration for job postings by experience level.")

# %%
agent.chat("What is the average duration for job applications by top 5 highest salary paying companies?")

# %%
agent.chat("Visualize average application duration across different countries.")

# %% [markdown]
# # *Geographic Insights*

# %%
agent.chat("List the top 10 countries with the most AI job postings.")

# %%
agent.chat("Which countries have the highest average salary in AI jobs?")

# %%
agent.chat("Visualize number of AI job postings by country.")
